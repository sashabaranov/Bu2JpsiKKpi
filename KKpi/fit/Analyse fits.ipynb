# %%
import ROOT
from ostap import rootnotes

# %%
chain = ROOT.TChain("ntuple")
chain.Add("fits.root")
# Out:
# 1

# %%
# not_bad = "i!=11 && i!=2 && i!=7 && i!=8 && i!=3"
not_bad = "1.0"

# %%
c1 = rootnotes.random_canvas()

# chain.Draw("SBu:minNll", not_bad, "colz")
chain.Draw("SBu", not_bad, "colz")

c1
# Out:
# <ROOT.TCanvas object ("f97de274-0c2d-48ed-9bcf-69214ce2470b") at 0x4714bd0>

# %%
c1 = rootnotes.random_canvas()

# chain.Draw("SBu:minNll", not_bad, "colz")
chain.Draw("error", not_bad, "colz")

c1
# Out:
# <ROOT.TCanvas object ("f9242386-2093-4a83-aef1-e6074a99f32b") at 0x4795b60>
