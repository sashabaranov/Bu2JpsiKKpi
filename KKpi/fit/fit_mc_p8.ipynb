# %% [markdown]
# # $B_{u} \to J/\psi KK\pi$ MC Pythia8 fit

# %% [markdown]
# __Basic imports__:

# %%
import ROOT, random
from   PyPAW import *
from   PyPAW.PyRoUts import *
import PyPAW.FitModels as Models

from ostap import *

# %% [markdown]
# __Variables__:

# %%
# Bu meson
m_Bu = ROOT.RooRealVar('m_Bu', 'mass(J/\psi K \pi \pi)', 5.15, 5.45)
nbin_Bu = 150
binning_b = (m_Bu.getMax() - m_Bu.getMin()) / nbin_Bu * 1000


selector_variables = [(m_Bu, lambda s: s.DTFm_b )]

# %% [markdown]
# __Project nTuple to RooFit's dataset__

# %%
from cuts import cuts_Bu, mctrue
from data import mc_Pythia6, mc_Pythia8, mc_total

from Ostap.Selectors import SelectorWithVarsCached

cuts_Bu += mctrue

sel_Bu = SelectorWithVarsCached(
    variables=selector_variables,
    selection=cuts_Bu,
    files=mc_Pythia8.files
)

if not sel_Bu._loaded_from_cache:
    mc_Pythia8.chain.process(sel_Bu)

ds_Bu = sel_Bu.dataset()
# Out:
# # Ostap.Selectors/ds_1000   INFO    TChain entries: 29552
# [ ######                                                                         ] 8%
# [ ############                                                                   ] 16%
# [ ##################                                                             ] 24%
# [ ########################                                                       ] 31%
# [ ###############################                                                ] 40%
# [ #####################################                                          ] 48%
# [ ############################################                                   ] 57%
# [ ###################################################                            ] 66%
# [ #########################################################                      ] 74%
# [ ################################################################               ] 83%
# [ #######################################################################        ] 92%
# [ ############################################################################## ] 100%
# [ ############################################################################## ] 100%
# # Ostap.Selectors/ds_1000   INFO    Events Processed/Total/Skept 5961/29552/0
# CUTS: " DTFchi2ndof > 0&& DTFchi2ndof < 5&& DTFctau > 0.25&& vchi2_b < 20&& pt_kaon[0] > 0.6 && pt_kaon[1] > 0.6&& pt_pion > 0.3&& m_jpsi    > 3.020 && m_jpsi    < 3.135&& minann_K  > 0.3&& ann_pion[0] > 0.3&& MIPCHI2DV_k1 > 12. && MIPCHI2DV_k2 > 12. && MIPCHI2DV_pi > 12.&& ((psi_l0tos & 2) == 2)&& ((psi_l1tos & 2) == 2)&& ((psi_l2tos & 2) == 2)&& mcTrueB && mcTruePsi && mcTrueK1 && mcTrueK2 && mcTruePi && mcTrueMu1 && mcTrueMu2"
# # Ostap.ZipShelve           INFO    Open DB: /home/sashab1/.ostap/cache/00fcf3508771f77cf418c32f5f10977e7e7029fc033a1de790fea920369ec5cd0596ccbf7482d75d4da3d999c511b3fed4411b517df68507ab19a101f47164ec.shelve

# %%
s1_Bu = Models.CB2_pdf(
    'Bu1',
    m_Bu.getMin(),
    m_Bu.getMax(),
    fixMass=5.2792e+0,
    fixSigma=0.008499e+0,
    fixAlphaL=2.1005,
    fixAlphaR=1.8805,
    fixNL=1.215,
    fixNR=2.765,
    mass=m_Bu
)


model_Bu = Models.Fit1D(
    signal=s1_Bu,
    background=Models.Bkg_pdf('BBu', mass=m_Bu), suffix='Bu'
)

model_Bu.b.fix(0)
model_Bu.background.tau.fix(0)
# Out:
# ( 0 +- 0 )

# %%
model_Bu.s.setMax(1.2 * len(ds_Bu))
ru, fu = model_Bu.fitTo(ds_Bu, draw=True, nbins=nbin_Bu)

model_Bu.signal.sigma.release()
model_Bu.signal.mean.release()
ru, fu = model_Bu.fitTo(ds_Bu, draw=True, nbins=nbin_Bu)

model_Bu.signal.aR.release()
model_Bu.signal.aL.release()
ru, fu = model_Bu.fitTo(ds_Bu, draw=True, nbins=nbin_Bu)

model_Bu.signal.nR.release()
model_Bu.signal.nL.release()

ru, fu = model_Bu.fitTo(ds_Bu, draw=True, nbins=nbin_Bu)

# %%
canvas = rootnotes.random_canvas(size=(1024, 768))

fu.SetXTitle("Inv.\,mass(J/\psi\,K\pi\pi), GeV/c^{2}}")
fu.SetYTitle("Events / %.1f MeV/c^{2}" % binning_b)

# fu.SetAxisRange(0.5, 5500, 'Y')

fu.Draw()


canvas.SetLogy()
canvas
# Out:
# <ROOT.TCanvas object ("7b75200d-549f-4f63-ab04-91c5c4d7abc9") at 0x774c040>

# %%
canvas = rootnotes.random_canvas(size=(1024, 768))

fu.SetXTitle("Inv.\,mass(J/\psi\,K\pi\pi), GeV/c^{2}}")
fu.SetYTitle("Events / %.1f MeV/c^{2}" % binning_b)

y_axis = fu.GetYaxis()
y_axis.SetTitleOffset(1.3)
fu.Draw()

canvas
# Out:
# <ROOT.TCanvas object ("1832aade-d52b-4736-89fa-25a0cda0d7ce") at 0x7c07720>

# %%
ipython_tools.params_table(ru)
# Out:
# Fit status: <b>Full, accurate covariance matrix</b><br/>minNll: <b>-67460.5725348</b><br/><table><tr><th>Name</th> <th>Value</th> <th>Min</th> <th>Max</th> </tr><tr><th>aR_Bu1</th> <th>( 2.12934 +- 0.137831 )</th> <th>0.0</th> <th>10.0</th></tr><tr><th>SBu</th> <th>( 5961.04 +- 77.1978 )</th> <th>0.0</th> <th>7153.2</th></tr><tr><th>aL_Bu1</th> <th>( 2.06346 +- 0.0854518 )</th> <th>0.0</th> <th>10.0</th></tr><tr><th>sigma_Bu1</th> <th>( 0.00528152 +- 7.77547e-05 )</th> <th>0.0</th> <th>0.103923048454</th></tr><tr><th>nR_Bu1</th> <th>( 2.03143 +- 0.550922 )</th> <th>0.0</th> <th>10.0</th></tr><tr><th>nL_Bu1</th> <th>( 0.780927 +- 0.184697 )</th> <th>0.0</th> <th>10.0</th></tr><tr><th>mean_Bu1</th> <th>( 5.27978 +- 7.87353e-05 )</th> <th>5.15</th> <th>5.45</th></tr></table>
