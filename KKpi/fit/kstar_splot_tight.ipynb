# %%
import ROOT, random

from Ostap import *
from Ostap.PyRoUts import *
from Ostap.Selectors import *
import Ostap.FitModels as Models
from MyFitModels import Charm3_pdf

from tools import *
from data import selection7

from ostap import *

def variate(var, minval=None, maxval=None, startval=None):
    if minval: var.setMin(minval)
    if maxval: var.setMax(maxval)
    if startval: var.setVal(startval)

# %%
# Bu meson
m_Bu = ROOT.RooRealVar('DTFm_b', 'mass(J/psiKKpi)', 5.22, 5.42)
import shelve
db = shelve.open("$KKpidir/fit/histos.shelve")

# kkk_hist = db['KKK']['MC']['p8_k3_cuts']
kpipi_hist = db['Kpipi']['MC']['p8_pi1']
# kkk = Models.H1D_pdf(name=kkk_hist.GetName(), mass=m_Bu, histo=smear_kkk(kkk_hist))
kpipi = Models.H1D_pdf(name=kpipi_hist.GetName(), mass=m_Bu, histo=smear_kpipi(kpipi_hist))

# %%
#
resonant = [
    ( 'DTFm_kk', "Inv. \, Mass(KK), GeV/c^2", 0.0, 20.0),
    ( 'DTFm_kpi', "Inv. \, Mass(K\pi), GeV/c^2", 0.0, 20.0),
]

# Bu meson
m_Bu = ROOT.RooRealVar('DTFm_b', 'mass(J/psiKKpi)', 5.22, 5.42)
nbin_Bu = 25
binning_b = (m_Bu.getMax() - m_Bu.getMin()) / nbin_Bu * 1000


# K*(892) mass
m_Kstar = ROOT.RooRealVar('DTFm_kpi', 'mass(K \pi)', 0.7, 1.1)
nbin_Kstar = 20
events_binning = (m_Kstar.getMax() - m_Kstar.getMin()) / nbin_Kstar * 1000

# For Breit-Wigner
mean_Kstar = ROOT.RooRealVar('mean_Kstar', 'mean(K*)', 0.85, 0.9)
mean_Kstar.fix(0.892)

width_Kstar = ROOT.RooRealVar('width_Kstar', 'width(Kstar0)', 0.0, 1.0)

# PhaseSpace range
low_kpi = ROOT.RooRealVar('low', 'low_KstarBg', 0.6, 0.7)
low_kpi.fix(0.634)

high_kpi = ROOT.RooRealVar('high', 'high_KstarBg', 1.3, 2.0)





selector_variables = [(m_Bu, lambda s: s.DTFm_b ), (m_Kstar, lambda s: s.DTFm_kpi )] + resonant

# %% [markdown]
# Basically, select all needed variables:

# %%
# Trigger
cuts_trg =  "((psi_l0tos & 2) == 2)"
cuts_trg += "&& ((psi_l1tos & 2) == 2)"
cuts_trg += "&& ((psi_l2tos & 2) == 2)"

# Cuts
cuts_ = " DTFchi2ndof > 0"
cuts_ += "&& DTFchi2ndof < 5"
cuts_ += "&& DTFctau > 0.25"
cuts_ += "&& vchi2_b < 20"
cuts_ += "&& pt_kaon[0] > 0.6 && pt_kaon[1] > 0.6"
cuts_ += "&& pt_pion > 0.3"
cuts_ += "&& m_jpsi    > 3.020 && m_jpsi    < 3.135"
cuts_ += "&& minann_K  > 0.3"
cuts_ += "&& ann_pion[0] > 0.3"
cuts_ += "&& MIPCHI2DV_k1 > 12. && MIPCHI2DV_k2 > 12. && MIPCHI2DV_pi > 12."

cuts_ += "&& " + cuts_trg

# %%
sel_Bu = SelectorWithVarsCached(
    variables=selector_variables,
    selection=cuts_,
    files=selection7.files
)

if not sel_Bu._loaded_from_cache:
    selection7.chain.process(sel_Bu)
ds_Bu = sel_Bu.dataset()
ds_Bu.Print('v')
# Out:
# # Ostap.ZipShelve           INFO    Open DB: /home/sashab1/.ostap/cache/79d400950908fb7b13d40cd8604ebb3ee30bf777933683463bce43b48a1063f217d5b29225b4a879599f0798095a30e8dfd9fd70ce25658459c7ea6f66d7f66d.shelve

# %%
canvas = rootnotes.random_canvas()

frame = m_Bu.frame(nbin_Bu)
ds_Bu.plotOn(frame)
frame.Draw()

canvas
# Out:
# <ROOT.TCanvas object ("d8d42701-72a3-4099-bb6d-84e7f9e89347") at 0x75f1e40>

# %%
s1_Bu = Models.CB2_pdf(
    'Bu1',
    m_Bu.getMin(),
    m_Bu.getMax(),
    fixMass=5.2792e+0,
    fixSigma=0.006,
    fixAlphaL=2.1018e+00,
    fixAlphaR=1.9818e+00,
    fixNL=6.1464e-01,
    fixNR=2.1291e+00,
    mass=m_Bu
)

bkg_Bu = Models.Bkg_pdf('BBu', mass=m_Bu, power=1)

# model_B = Models.Fit1D(
#     signal=s1_Bu,
#     background=bkg_Bu,
#     components=[kkk]
# )


model_B = Charm3_pdf(
    signal=s1_Bu,
    signal2=kpipi,
    background=bkg_Bu,
)


# bkg_Bu.tau.fix(0)
# bkg_Bu.phis[0].fix(0)

# %%
c1 = rootnotes.random_canvas(size=(1024, 768))


ru, fu = model_B.fitTo(ds_Bu, draw=True, nbins=nbin_Bu)

model_B.signal.mean.release()
model_B.signal.sigma.release()

ru, fu = model_B.fitTo(ds_Bu, draw=True, nbins=nbin_Bu)



fu.SetXTitle('Inv.\,mass(J/\psi KK\pi), GeV/c^{2}}')
fu.SetYTitle("Events / %.1f MeV/c^{2}" % binning_b)

fu.Draw()
model_B.legend.Draw()

c1
# Out:
# <ROOT.TCanvas object ("acfdde5e-0fa0-4b82-b8c1-618740a494e0") at 0x6c67400>

# %%
ipython_tools.params_table(ru)
# Out:
# Fit status: <b>Full, accurate covariance matrix</b><br/>minNll: <b>-12749.556245</b><br/><table><tr><th>Name</th> <th>Value</th> <th>Min</th> <th>Max</th> </tr><tr><th>B</th> <th>( 1042.05 +- 57.5905 )</th> <th>0.0</th> <th>1800.0</th></tr><tr><th>phi1_BBu</th> <th>( -1.53482e-05 +- 0.37242 )</th> <th>-3.5</th> <th>3.5</th></tr><tr><th>S2</th> <th>( 368.502 +- 45.5155 )</th> <th>0.0</th> <th>2383.79661228</th></tr><tr><th>S</th> <th>( 177.527 +- 20.5834 )</th> <th>0.0</th> <th>2383.79661228</th></tr><tr><th>sigma_Bu1</th> <th>( 0.00503876 +- 0.000557148 )</th> <th>0.0</th> <th>0.0692820323028</th></tr><tr><th>tau_BBu</th> <th>( -5.797 +- 7.59605 )</th> <th>-184.20680744</th> <th>184.20680744</th></tr><tr><th>mean_Bu1</th> <th>( 5.28122 +- 0.00063838 )</th> <th>5.22</th> <th>5.42</th></tr></table>

# %%
model_B.sPlot(ds_Bu)
# Out:
# <ROOT.RooStats::SPlot object ("sPlot_1000") at 0x6cfd570>

# %% [markdown]
# ### Now fit $K^{*}$

# %%
hist = ROOT.TH1F(hID(), '', nbin_Kstar, m_Kstar.getMin(), m_Kstar.getMax())
hist.Sumw2()

ds_Bu.project(hist, "DTFm_kpi", "S_sw")
# Out:
# 1588L

# %%
canvas = rootnotes.random_canvas(size=(1024, 768))
hist.Draw()
canvas
# Out:
# <ROOT.TCanvas object ("2b1a84a5-0216-43f1-b7ba-fbf3e2fb7807") at 0x6c69070>

# %%
m = VE(0.8916, 0.02**2)
bw = cpp.Gaudi.Math.BreitWigner(m.value(), m.error(), 0.493, 0.139, 1, 1)


s_Ks =  Models.BreitWigner_pdf(
   "Ks1",
   m_Kstar.getMin(),
   m_Kstar.getMin(),
   bw,
   mass=m_Kstar,
   mean        = mean_Kstar , 
   gamma       = width_Kstar)


ps = cpp.Gaudi.Math.PhaseSpaceNL(low_kpi, high_kpi, 2, 4) 


model_Ks = Models.Fit1D(
    signal=s_Ks,
    background=Models.PSPol_pdf( 'Bkg' , m_Kstar, ps , 0 ),
    suffix='Ks'
)

model_Ks.signal.mean.fix(0.89581)
model_Ks.signal.gamma.fix(47.4e-3)
# Out:
# ( 0.0474 +- 0 )

# %%
canvas = rootnotes.random_canvas(size=(1024, 768))

r, f = model_Ks.fitHisto(hist, draw=True)

# model_Ks.signal.gamma.release()
# r, f = model_Ks.fitHisto(hist, draw=True)

# model_Ks.signal.mean.release()
# r, f = model_Ks.fitHisto(hist, draw=True)


f.SetTitle("")
f.SetXTitle("Inv.\,mass(K\pi), GeV/c^{2}}")
f.SetYTitle("Events / %.1f MeV/c^{2}" % events_binning)



canvas
# Out:
# <ROOT.TCanvas object ("a7f9e4fd-b491-4c2a-8051-44203e2d7105") at 0x70e44b0>

# %%
ipython_tools.params_table(r)
# Out:
# Fit status: <b>Full, accurate covariance matrix</b><br/>minNll: <b>-976.722742001</b><br/><table><tr><th>Name</th> <th>Value</th> <th>Min</th> <th>Max</th> </tr><tr><th>SKs</th> <th>( 125.536 +- 14.3496 )</th> <th>0.0</th> <th>1000000.0</th></tr><tr><th>BKs</th> <th>( 51.9757 +- 11.5049 )</th> <th>0.0</th> <th>1000000.0</th></tr></table>
