# %%
import ROOT, random

from Ostap import *
from Ostap.PyRoUts import *
from Ostap.Selectors import *
import Ostap.FitModels as Models
from MyFitModels import Charm3_pdf

from tools import *
from data import selection7

from ostap import *
from mc_average import *


def variate(var, minval=None, maxval=None, startval=None):
    if minval: var.setMin(minval)
    if maxval: var.setMax(maxval)
    if startval: var.setVal(startval)

# %%
#
resonant = [
    ( 'DTFm_kk', "Inv. \, Mass(KK), GeV/c^2", 1.0, 1.20),
]

# Bu meson
m_Bu = ROOT.RooRealVar('DTFm_b', 'mass(J/psiKKpi)', 5.22, 5.34)
nbin_Bu = 30
binning_b = (m_Bu.getMax() - m_Bu.getMin()) / nbin_Bu * 1000


# Phi mass
m_Phi = ROOT.RooRealVar('DTFm_kk', 'mass(KK)', 1.0, 1.20)
nbin_Phi = 40
events_binning = (m_Phi.getMax() - m_Phi.getMin()) / nbin_Phi * 1000


# For Breit-Wigner
mean_Phi = ROOT.RooRealVar('mean_Phi', 'mean(Phi)', 1.0, 1.05)
mean_Phi.fix(1.02)

width_Phi = ROOT.RooRealVar('width_Phi', 'width(Phi)', 0.0, 1.0)

# PhaseSpace range
low_kk = ROOT.RooRealVar('low', 'low_PhiBg', 0.9, 1.0)
low_kk.fix(0.986)

high_kk = ROOT.RooRealVar('high', 'high_PhiBg', 2.0, 2.1)





selector_variables = [(m_Bu, lambda s: s.DTFm_b )] + resonant

# %% [markdown]
# Basically, select all needed variables:

# %%
# Trigger
cuts_trg =  "((psi_l0tos & 2) == 2)"
cuts_trg += "&& ((psi_l1tos & 2) == 2)"
cuts_trg += "&& ((psi_l2tos & 2) == 2)"

# Cuts
cuts_ = " DTFchi2ndof > 0"
cuts_ += "&& DTFchi2ndof < 5"
cuts_ += "&& DTFctau > 0.25"
cuts_ += "&& vchi2_b < 20"
cuts_ += "&& pt_kaon[0] > 0.6 && pt_kaon[1] > 0.6"
cuts_ += "&& pt_pion > 0.3"
cuts_ += "&& m_jpsi    > 3.020 && m_jpsi    < 3.135"
cuts_ += "&& minann_K  > 0.3"
cuts_ += "&& ann_pion[0] > 0.3"
cuts_ += "&& MIPCHI2DV_k1 > 12. && MIPCHI2DV_k2 > 12. && MIPCHI2DV_pi > 12."

cuts_ += "&& " + cuts_trg

# %%
sel_Bu = SelectorWithVarsCached(
    variables=selector_variables,
    selection=cuts_,
    files=selection7.files
)

if not sel_Bu._loaded_from_cache:
    selection7.chain.process(sel_Bu)
ds_Bu = sel_Bu.dataset()
ds_Bu.Print('v')
# Out:
# # Ostap.Selectors/ds_1000   INFO    TChain entries: 4020930
# [ ####                                                                           ] 6%
# [ ########                                                                       ] 11%
# [ #############                                                                  ] 17%
# [ #################                                                              ] 23%
# [ ######################                                                         ] 29%
# [ ############################                                                   ] 37%
# [ ###################################                                            ] 45%
# [ #########################################                                      ] 53%
# [ ###############################################                                ] 61%
# [ #####################################################                          ] 68%
# [ ###########################################################                    ] 76%
# [ ###############################################################                ] 82%
# [ ######################################################################         ] 90%
# [ ###########################################################################    ] 97%
# [ ############################################################################## ] 100%
# [ ############################################################################## ] 100%
# # Ostap.Selectors/ds_1000   INFO    Events Processed/Total/Skept 7213/4020930/6604
# CUTS: " DTFchi2ndof > 0&& DTFchi2ndof < 5&& DTFctau > 0.25&& vchi2_b < 20&& pt_kaon[0] > 0.6 && pt_kaon[1] > 0.6&& pt_pion > 0.3&& m_jpsi    > 3.020 && m_jpsi    < 3.135&& minann_K  > 0.3&& ann_pion[0] > 0.3&& MIPCHI2DV_k1 > 12. && MIPCHI2DV_k2 > 12. && MIPCHI2DV_pi > 12.&& ((psi_l0tos & 2) == 2)&& ((psi_l1tos & 2) == 2)&& ((psi_l2tos & 2) == 2)"
# # Ostap.ZipShelve           INFO    Open DB: /home/sashab1/.ostap/cache/b2f1bf35dc29e6f81192b556b2b155a0b1dc4ef0f12d189ef0d53cdb4efed9455089ac7abc3277f8ff8899f28cbb3c094b34bed9416fea954b501a598ebb967c.shelve

# %%
canvas = rootnotes.random_canvas()

frame = m_Bu.frame(nbin_Bu)
ds_Bu.plotOn(frame)
frame.Draw()

canvas
# Out:
# <ROOT.TCanvas object ("40eea159-779c-4093-b167-eb8bcd96791d") at 0xbf1efd0>

# %%
s1_Bu = Models.CB2_pdf(
    'Bu1',
    m_Bu.getMin(),
    m_Bu.getMax(),
    fixMass=5.28,
    fixSigma=5.75e-3,
    fixAlphaL=avg_mc("aL_Bu1"),
    fixAlphaR=avg_mc("aR_Bu1"),
    fixNL=avg_mc("nL_Bu1"),
    fixNR=avg_mc("nR_Bu1"),
    mass=m_Bu
)

bkg_Bu = Models.Bkg_pdf('BBu', mass=m_Bu, power=1)

# model_B = Models.Fit1D(
#     signal=s1_Bu,
#     background=bkg_Bu,
#     components=[kkk]
# )


model_B = Charm3_pdf(
    signal=s1_Bu,
    background=bkg_Bu,
)


# bkg_Bu.tau.fix(0)
# bkg_Bu.phis[0].fix(0)

# %%
c1 = rootnotes.random_canvas(size=(1024, 768))


ru, fu = model_B.fitTo(ds_Bu, draw=True, nbins=nbin_Bu)

model_B.signal.mean.release()
model_B.signal.sigma.release()

ru, fu = model_B.fitTo(ds_Bu, draw=True, nbins=nbin_Bu)


fu.SetTitle("")
fu.SetXTitle('Inv. mass(J/#psi KK#pi), GeV/c^{2}')
fu.SetYTitle("Events / %.1f MeV/c^{2}" % binning_b)

fu.Draw()
model_B.legend.Draw()
model_B.legend.Draw()

c1
# Out:
# <ROOT.TCanvas object ("fec80b4d-5261-4bed-8ad8-0bae217752a6") at 0xbec88c0>

# %%
ipython_tools.params_table(ru)
# Out:
# Fit status: <b>Full, accurate covariance matrix</b><br/>minNll: <b>-4624.63673956</b><br/><table><tr><th>Name</th> <th>Value</th> <th>Min</th> <th>Max</th> </tr><tr><th>B</th> <th>( 548.846 +- 25.1531 )</th> <th>0.0</th> <th>1800.0</th></tr><tr><th>phi1_BBu</th> <th>( 0.00204162 +- 0.192922 )</th> <th>-3.5</th> <th>3.5</th></tr><tr><th>S</th> <th>( 60.1796 +- 12.0041 )</th> <th>0.0</th> <th>1026.9351043</th></tr><tr><th>sigma_Bu1</th> <th>( 0.00250885 +- 0.000641501 )</th> <th>0.0</th> <th>0.0415692193817</th></tr><tr><th>tau_BBu</th> <th>( -6.51632 +- 6.55815 )</th> <th>-307.011345733</th> <th>307.011345733</th></tr><tr><th>mean_Bu1</th> <th>( 5.28034 +- 0.000568365 )</th> <th>5.22</th> <th>5.34</th></tr></table>

# %%
model_B.sPlot(ds_Bu)
# Out:
# <ROOT.RooStats::SPlot object ("sPlot_1000") at 0xbfa1610>

# %% [markdown]
# ### Now fit $\phi$

# %%
hist = ROOT.TH1F(hID(), '', nbin_Phi, m_Phi.getMin(), m_Phi.getMax())
hist.Sumw2()

ds_Bu.project(hist, "DTFm_kk", "S_sw")
# Out:
# 609L

# %%
canvas = rootnotes.random_canvas(size=(1024, 768))
hist.Draw()
canvas
# Out:
# <ROOT.TCanvas object ("3109d26c-07bf-49ef-bd82-34e873bd4b22") at 0xc0e1250>

# %%
bw     = cpp.Gaudi.Math.Phi0 ( 1.0195 ,
                               0.0043 ,
                               0.4937 )

s_Phi =  Models.BreitWigner_pdf(
   "Phi1",
   m_Phi.getMin(),
   m_Phi.getMin(),
   bw,
   mass=m_Phi,
#    convolution = 2e-3,
   fixMass = 1.0195,
   fixGamma = 4.3e-3
)


ps2    = cpp.Gaudi.Math.PhaseSpaceNL ( 2*0.4937 , 5.278-3.096 , 2 , 4 ) 

model_Phi = Models.Fit1D(
    signal=s_Phi,
    background=Models.PSPol_pdf( 'Bkg' , m_Phi , ps2 , 0 ),
    suffix='Phi'
)

# %%
canvas = rootnotes.random_canvas(size=(1024, 768))

r, f = model_Phi.fitHisto(hist, draw=True)


model_Phi.signal.mean.release()
r, f = model_Phi.fitHisto(hist, draw=True)

f.SetTitle('')
f.SetXTitle("Inv.\,mass(KK), GeV/c^{2}}")
f.SetYTitle("Events / %.1f MeV/c^{2}" % events_binning)



canvas
# Out:
# <ROOT.TCanvas object ("603ece1e-5502-445d-a822-a83125c2bc0a") at 0xb968510>

# %%
ipython_tools.params_table(r)
# Out:
# Fit status: <b>Full, accurate covariance matrix</b><br/>minNll: <b>-304.872672736</b><br/><table><tr><th>Name</th> <th>Value</th> <th>Min</th> <th>Max</th> </tr><tr><th>mean_Phi1</th> <th>( 1.02272 +- 0.000464806 )</th> <th>1.0</th> <th>1.2</th></tr><tr><th>BPhi</th> <th>( 40.8095 +- 6.86062 )</th> <th>0.0</th> <th>1000000.0</th></tr><tr><th>SPhi</th> <th>( 19.3672 +- 5.06223 )</th> <th>0.0</th> <th>1000000.0</th></tr></table>

# %% [markdown]
# ## Weights

# %%
dataW = ds_Bu.makeWeighted ( 'S_sw' )

# %%
canvas = rootnotes.random_canvas()

rW,u  = model_Phi.fitTo ( dataW , True , nbin_Phi , False ) 

canvas
# Out:
# <ROOT.TCanvas object ("92a8e30c-9293-45b8-90a3-a9f17717929a") at 0xbf3dab0>

# %%
canvas = rootnotes.random_canvas()
rWt,u = model_Phi.fitTo ( dataW , True , 25 , False , ROOT.RooFit.SumW2Error ( True  ) )
canvas
# Out:
# <ROOT.TCanvas object ("4ca77679-97ba-479e-b6c2-4e0d31315fe1") at 0xbf2eb20>

# %%
canvas = rootnotes.random_canvas()
rWf,u = model_Phi.fitTo ( dataW , True , 25 , False , ROOT.RooFit.SumW2Error ( False ) )
canvas
# Out:
# <ROOT.TCanvas object ("c44204f1-3895-40f3-97a5-aafa3aab5486") at 0xd5c29e0>

# %%
print  'HISTO           %s ' % r  ('SPhi') [0]
print  'WEIGHTED        %s ' % rW  ('SPhi') [0]
print  'WEIGHTED(True)  %s ' % rWt ('SPhi') [0] 
print  'WEIGHTED(False) %s ' % rWf ('SPhi') [0]
# Out:
# HISTO           ( 19.3672 +- 5.06223 )
# WEIGHTED        ( 18.6979 +- 5.02177 )
# WEIGHTED(True)  ( 18.7082 +- 6.01781 )
# WEIGHTED(False) ( 18.7075 +- 5.02348 )
