# %% [markdown]
# # sPlot-fitting of $\psi(2S)$ resonanse in $B_u \to J/\psi K \pi\pi$ - wide $\psi(2S)$ interval

# %% [markdown]
# Import basic things:

# %%
import ROOT, random
from   Ostap import *
from   Ostap.PyRoUts import *
import Ostap.FitModels as Models

from ostap import *
from mc_average import *
# Out:
# importing IPython notebook from mc_average.ipynb
# importing IPython notebook from fit_mc_pythia6.ipynb
# # Ostap.ZipShelve           INFO    Open DB: /home/sashab1/.ostap/cache/b6312054b82f905767adfe205e8d48d6541d0c8c515642417a253a90bd1fc74db9f7e4a828280be7b73d0251682e63c2315f779113fd5c1bb2ea3ccabed9866d.shelve
# importing IPython notebook from fit_mc_pythia8.ipynb
# # Ostap.ZipShelve           INFO    Open DB: /home/sashab1/.ostap/cache/1f2de635d931dc29ff0a43571472c614c29e2e61b65818d8fe9dbcd806e1afdde8b667cfd6015c68763b2dfbe1d443a7f7779f8d9aad8f2f1ebffbe26672f934.shelve
# RooFitResult

# %% [markdown]
# __Variables__

# %%
from variables import *

# Resonanse
m_R = ROOT.RooRealVar('m_R', '', 3.6, 3.75)
nbin_R = 150
binning_R = (m_R.getMax() - m_R.getMin()) / nbin_R * 1000

selector_variables = [(m_Bu, lambda s: s.DTFm_b ), (m_R, lambda s: s.m134c2 )]

# %% [markdown]
# Project tuple to RooFits dataset:

# %%
from cuts import cuts_Bu
from data import selection7

from Ostap.Selectors import SelectorWithVarsCached

sel_Bu = SelectorWithVarsCached(
    variables=selector_variables,
    selection=cuts_Bu,
    files=selection7.files
)

if not sel_Bu._loaded_from_cache:
    selection7.chain.process(sel_Bu)


ds_Bu = sel_Bu.dataset()
ds_Bu.Print('v')
# Out:
# # Ostap.ZipShelve           INFO    Open DB: /home/sashab1/.ostap/cache/edd67e98a2275e5abce1db0aed12b9d70f9dd494ce1795adb5168a9d0c2dfaaa299baa8f83de34ec8243d6ee4291285a6ac527e937dbda848caa1edcb92230d9.shelve

# %%
canvas = rootnotes.random_canvas()

frame = m_Bu.frame()
ds_Bu.plotOn(frame)
frame.Draw()

canvas
# Out:
# <ROOT.TCanvas object ("4b74f806-40e6-4280-a475-162768ce51ba") at 0x94a9c70>

# %% [markdown]
# __Fit model__

# %%
s1_Bu = Models.CB2_pdf(
    'Bu1',
    m_Bu.getMin(),
    m_Bu.getMax(),
    fixMass=5.2792e+0,
    fixSigma=avg_mc("sigma_Bu1"),
    fixAlphaL=avg_mc("aL_Bu1"),
    fixAlphaR=avg_mc("aR_Bu1"),
    fixNL=avg_mc("nL_Bu1"),
    mass=m_Bu
)

s1_Bu.nR.setMax(20.0)
s1_Bu.nR.fix(avg_mc("nR_Bu1"))

model_Bu = Models.Fit1D(
    signal=s1_Bu,
    background=Models.Bkg_pdf('BBu', mass=m_Bu, power=0), 
    suffix='Bu'
)

# %% [markdown]
# Do fit:

# %%
# model_Bu.background.tau.fix(0)
model_Bu.s.setMax(1.2 * len(ds_Bu))

model_Bu.signal.sigma.release()
model_Bu.signal.mean.release()

ru, fu = model_Bu.fitTo(ds_Bu, draw=True, nbins=nbin_Bu)

# model_Bu.signal.aL.release()
# model_Bu.signal.aR.release()
# ru, fu = model_Bu.fitTo(ds_Bu, draw=True, nbins=nbin_Bu)

# model_Bu.signal.nL.release()
# model_Bu.signal.nR.release()
# ru, fu = model_Bu.fitTo(ds_Bu, draw=True, nbins=nbin_Bu)

# %% [markdown]
# Fit plots
# ---

# %%
c1 = rootnotes.random_canvas(size=(1024, 768))

fu.SetXTitle('Inv. mass(J/\psi\,K\pi\pi), GeV/c^2')
fu.SetYTitle("Events / %.1f MeV/c^{2}" % binning_b)

fu.Draw()
c1.SetLogy()
c1
# Out:
# <ROOT.TCanvas object ("f0b6c05f-c296-4d55-990f-0d23eaed29a1") at 0x788da60>

# %%
c1 = rootnotes.random_canvas(size=(1024, 768))

fu.SetXTitle('Inv. mass(J/\psi\,K\pi\pi), GeV/c^2')
fu.SetYTitle("Events / %.1f MeV/c^{2}" % binning_b)

fu.Draw()
# c1.SetLogy()
y_axis = fu.GetYaxis()
y_axis.SetTitleOffset(1.3)
c1
# Out:
# <ROOT.TCanvas object ("95eb1359-3511-44cb-8203-75a7d4dd94a0") at 0x7a1e0f0>

# %% [markdown]
# Fit results
# ---

# %%
ipython_tools.params_table(ru)
# Out:
# Fit status: <b>Full, accurate covariance matrix</b><br/>minNll: <b>-111243.105282</b><br/><table><tr><th>Name</th> <th>Value</th> <th>Min</th> <th>Max</th> </tr><tr><th>tau_BBu</th> <th>( -2.62654 +- 0.854044 )</th> <th>-122.804538293</th> <th>122.804538293</th></tr><tr><th>BBu</th> <th>( 260.62 +- 24.4442 )</th> <th>0.0</th> <th>1000000.0</th></tr><tr><th>sigma_Bu1</th> <th>( 0.00771541 +- 7.54429e-05 )</th> <th>0.0</th> <th>0.103923048454</th></tr><tr><th>mean_Bu1</th> <th>( 5.28069 +- 8.74873e-05 )</th> <th>5.15</th> <th>5.45</th></tr><tr><th>SBu</th> <th>( 9600.45 +- 99.6788 )</th> <th>0.0</th> <th>11833.2</th></tr></table>

# %% [markdown]
# sPlot
# ---

# %%
model_Bu.sPlot(ds_Bu)
# Out:
# <ROOT.RooStats::SPlot object ("sPlot_1000") at 0xbc5cf10>

# %% [markdown]
# Project mass of $J/\psi \pi\pi$ on histogram with sPlot weight:

# %%
h = ROOT.TH1F("h_R", "", nbin_R, m_R.getMin(), m_R.getMax())
h.SetMinimum(0.0)
h.Sumw2()


# for j in xrange(0, h.GetNbinsX()):
#     h.SetBinContent(j, 0.0)
#     h.SetBinError(j, 0.0)

ds_Bu.project(h, "m_R", "SBu_sw")
h.Sumw2()

# %% [markdown]
# Resonanse fit model:

# %%
s1_Psi = Models.CB2_pdf(
    'psi2s',
    m_R.getMin(),
    m_R.getMax(),
    fixMass=3.686,
    fixSigma=0.002201,
    fixAlphaL=1.896,
    fixAlphaR=1.584,
    fixNL=0.912,
    fixNR=8.8,
    mass=m_R
)

bkg_psi = Models.PSNL_pdf("bkg", m_R, 3, 4, 3.096 + 2*0.139, 5.45   - 0.5)
model_Resonant = Models.Fit1D(
    signal=s1_Psi,
#     background=Models.Bkg_pdf('BRes', mass=m_R, power=1),
    background=bkg_psi,
    suffix='Res'
)

# %% [markdown]
# Resonanse fit:

# %%
r, f = model_Resonant.fitHisto(h, draw=True)
model_Resonant.signal.mean.release()
model_Resonant.signal.sigma.release()
r, f = model_Resonant.fitHisto(h, draw=True)

# %% [markdown]
# Resonanse fit plot
# ---

# %%
c2 = rootnotes.random_canvas(size=(1024, 768))

f.SetYTitle("Events / %.1f MeV/c^{2}" % binning_R)
f.SetXTitle("Inv. Mass(J/\psi \pi \pi), GeV/c^{2}")
y_axis = f.GetYaxis()
y_axis.SetTitleOffset(1.3)


f.Draw()


c2
# Out:
# <ROOT.TCanvas object ("8d0ef49c-8fee-46ee-919b-1d41986939cb") at 0xbffc410>

# %%
c2 = rootnotes.random_canvas(size=(1024, 768))

f.SetYTitle("Events / %.1f MeV/c^{2}" % binning_R)
f.SetXTitle("Inv. Mass(J/\psi \pi \pi), GeV/c^{2}")
f.Draw()
f.SetAxisRange(1, 5500, 'Y')

c2.SetLogy()
c2
# Out:
# <ROOT.TCanvas object ("99c274c0-5610-4b25-87a9-0c3db5ec38ff") at 0xbfd56d0>

# %%
ipython_tools.params_table(r)
# Out:
# Fit status: <b>Full, accurate covariance matrix</b><br/>minNll: <b>-117908.103113</b><br/><table><tr><th>Name</th> <th>Value</th> <th>Min</th> <th>Max</th> </tr><tr><th>mean_psi2s</th> <th>( 3.68639 +- 2.97813e-05 )</th> <th>3.6</th> <th>3.75</th></tr><tr><th>sigma_psi2s</th> <th>( 0.00247296 +- 2.63714e-05 )</th> <th>0.0</th> <th>0.0519615242271</th></tr><tr><th>SRes</th> <th>( 9241.48 +- 97.2915 )</th> <th>0.0</th> <th>1000000.0</th></tr><tr><th>BRes</th> <th>( 358.937 +- 24.1479 )</th> <th>0.0</th> <th>1000000.0</th></tr></table>
