# %% [markdown]
# # $B_{u} \to J/\psi K\pi\pi$ MC Pythia6 fit

# %% [markdown]
# __Basic imports__:

# %%
import ROOT, random
from   Ostap import *
from   Ostap.PyRoUts import *
import Ostap.FitModels as Models

from ostap import rootnotes

# %% [markdown]
# __Variables__:

# %%
from variables import *

# %% [markdown]
# __Project nTuple to RooFit's dataset__

# %%
from cuts import cuts_mc
from data import mc_Pythia6, mc_Pythia8, mc_total

from Ostap.Selectors import SelectorWithVarsCached

sel_Bu = SelectorWithVarsCached(
    variables=selector_variables,
    selection=cuts_mc,
    files=mc_Pythia6.files
)

if not sel_Bu._loaded_from_cache:
    mc_Pythia6.chain.process(sel_Bu)

ds_Bu = sel_Bu.dataset()
# Out:
# # Ostap.ZipShelve           INFO    Open DB: /home/sashab1/.ostap/cache/e1c8ee543d3941a8ed845424a45ff121522d59ee4d89abd47f720aa567e20c623f6b50000e1a9323b58b70a730e89c041c650dc60c152729b7c1963e55bd9789.shelve

# %%
s1_Bu = Models.CB2_pdf(
    'Bu1',
    m_Bu.getMin(),
    m_Bu.getMax(),
    fixMass=5.2792e+0,
    fixSigma=0.008499e+0,
    fixAlphaL=1.6940e+00,
    fixAlphaR=1.6167e+00,
    fixNL=1.5287e+00,
    fixNR=1.0000e+01,
    mass=m_Bu
)

# def variate(var, minval=None, maxval=None, startval=None):
#     if minval: var.setMin(minval)
#     if maxval: var.setMax(maxval)
#     if startval: var.setVal(startval)

s1_Bu.nR.setMax(20.0)

model_Bu = Models.Fit1D(
    signal=s1_Bu,
    background=Models.Bkg_pdf('BBu', mass=m_Bu), suffix='Bu'
)

model_Bu.b.fix(0)
model_Bu.background.tau.fix(0)
# Out:
# ( 0 +- 0 )

# %%
model_Bu.s.setMax(1.2 * len(ds_Bu))
ru, fu = model_Bu.fitTo(ds_Bu, draw=True, nbins=nbin_Bu)

model_Bu.signal.sigma.release()
model_Bu.signal.mean.release()
ru, fu = model_Bu.fitTo(ds_Bu, draw=True, nbins=nbin_Bu)

model_Bu.signal.aR.release()
model_Bu.signal.aL.release()
ru, fu = model_Bu.fitTo(ds_Bu, draw=True, nbins=nbin_Bu)

model_Bu.signal.nR.release()
model_Bu.signal.nL.release()

ru, fu = model_Bu.fitTo(ds_Bu, draw=True, nbins=nbin_Bu)

# %%
canvas = rootnotes.random_canvas(size=(1024, 768))

fu.SetXTitle("Inv. mass(J/#psi K#pi#pi), GeV/c^{2}")
fu.SetYTitle("Events / %.1f MeV/c^{2}" % binning_b)

fu.Draw()


canvas.SetLogy()
canvas
# Out:
# <ROOT.TCanvas object ("4474bd5d-405b-422c-b14f-2ad471ce6dd9") at 0x9e4ec00>

# %%
canvas = rootnotes.random_canvas(size=(1024, 768))

fu.SetXTitle("Inv. mass(J/#psi K#pi#pi), GeV/c^{2}")
fu.SetYTitle("Events / %.1f MeV/c^{2}" % binning_b)

# fu.SetAxisRange(0, 1000, 'Y')
y_axis = fu.GetYaxis()
y_axis.SetTitleOffset(1.3)
fu.Draw()

canvas
# Out:
# <ROOT.TCanvas object ("8b17f2f9-774e-4471-8ac5-1fa24dd14402") at 0x9d52640>

# %%
from ostap import ipython_tools

ipython_tools.params_table(ru)
# Out:
# Fit status: <b>Full, accurate covariance matrix</b><br/>minNll: <b>-249334.590794</b><br/><table><tr><th>Name</th> <th>Value</th> <th>Min</th> <th>Max</th> </tr><tr><th>aR_Bu1</th> <th>( 1.99619 +- 0.0737783 )</th> <th>0.0</th> <th>10.0</th></tr><tr><th>SBu</th> <th>( 20230.2 +- 142.229 )</th> <th>0.0</th> <th>24276.0</th></tr><tr><th>aL_Bu1</th> <th>( 1.99244 +- 0.0512974 )</th> <th>0.0</th> <th>10.0</th></tr><tr><th>sigma_Bu1</th> <th>( 0.00626565 +- 5.92694e-05 )</th> <th>0.0</th> <th>0.103923048454</th></tr><tr><th>nR_Bu1</th> <th>( 2.59809 +- 0.374444 )</th> <th>0.0</th> <th>20.0</th></tr><tr><th>nL_Bu1</th> <th>( 0.615672 +- 0.0994458 )</th> <th>0.0</th> <th>10.0</th></tr><tr><th>mean_Bu1</th> <th>( 5.27966 +- 5.31835e-05 )</th> <th>5.15</th> <th>5.45</th></tr></table>
