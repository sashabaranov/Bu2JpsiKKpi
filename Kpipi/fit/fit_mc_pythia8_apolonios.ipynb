# %% [markdown]
# # $B_{u} \to J/\psi K\pi\pi$ MC Pythia8 fit - Apolonios model

# %% [markdown]
# __Basic imports__:

# %%
import ROOT, random
from   PyPAW import *
from   PyPAW.PyRoUts import *
import PyPAW.FitModels as Models

from ostap import rootnotes
# Out:
# # Ostap.PyRoUts             INFO    Zillions of decorations for ROOT   objects
# # setting LC_ALL to "C"

# %% [markdown]
# __Variables__:

# %%
from variables import *

# %% [markdown]
# __Project nTuple to RooFit's dataset__

# %%
from cuts import cuts_Bu, mctrue
from data import mc_Pythia6, mc_Pythia8, mc_total

from PyPAW.Selectors import SelectorWithVarsCached

cuts_Bu += mctrue

sel_Bu = SelectorWithVarsCached(
    variables=selector_variables,
    selection=cuts_Bu,
    files=mc_Pythia8.files
)

if not sel_Bu._loaded_from_cache:
    mc_Pythia8.chain.process(sel_Bu)

ds_Bu = sel_Bu.dataset()
# Out:
# DEFINE default storage type to be TTree!
# # data                      INFO    Selection 7: <Luminosity: ( 3082.18 +- 61.9831 )pb-1; #files: 201; Entries: 14367852>
# # Ostap.ZipShelve           INFO    Open DB: /home/sashab1/.ostap/cache/c36086e7a07ed18afa94fbf887fb8d4f389826e1cc617d3b6be70306e6c21ee111f1942517d32279a2b866684f763545cbcc9aef6526c1e37039b05173889694.shelve

# %%
# s1_Bu = Models.CB2_pdf(
#     'Bu1',
#     m_Bu.getMin(),
#     m_Bu.getMax(),
#     fixMass=5.2792e+0,
#     fixSigma=0.008499e+0,
#     fixAlphaL=2.1005,
#     fixAlphaR=1.8805,
#     fixNL=1.215,
#     fixNR=2.765,
#     mass=m_Bu
# )

def variate(var, minval=None, maxval=None, startval=None):
    if minval: var.setMin(minval)
    if maxval: var.setMax(maxval)
    if startval: var.setVal(startval)

s1_Bu = Models.Apolonios_pdf(
    'Bu1',
    m_Bu.getMin(),
    m_Bu.getMax(),
    fixMass=5.2792e+0,
    fixSigma=0.008499e+0,
    mass=m_Bu
)

variate(s1_Bu.n, 0, 1000)
variate(s1_Bu.b, 1e-8, 1000)
variate(s1_Bu.alpha, 3.7, 11)

model_Bu = Models.Fit1D(
    signal=s1_Bu,
    background=Models.Bkg_pdf('BBu', mass=m_Bu), suffix='Bu'
)

model_Bu.b.fix(0)
model_Bu.background.tau.fix(0)
# Out:
# ( 0 +- 0 )

# %%
# model_Bu.signal.alpha.fix(3.0)

# %%
model_Bu.s.setMax(1.2 * len(ds_Bu))
ru, fu = model_Bu.fitTo(ds_Bu, draw=True, nbins=nbin_Bu)

model_Bu.signal.sigma.release()
model_Bu.signal.mean.release()
ru, fu = model_Bu.fitTo(ds_Bu, draw=True, nbins=nbin_Bu)

# model_Bu.signal.aR.release()
# model_Bu.signal.aL.release()
model_Bu.signal.alpha.release()
ru, fu = model_Bu.fitTo(ds_Bu, draw=True, nbins=nbin_Bu)

# model_Bu.signal.nR.release()
# model_Bu.signal.nL.release()

# ru, fu = model_Bu.fitTo(ds_Bu, draw=True, nbins=nbin_Bu)

# %%
canvas = rootnotes.random_canvas(size=(1024, 768))

fu.SetXTitle("Inv. mass(J/#psi K#pi#pi), GeV/c^{2}")
fu.SetYTitle("Events / %.1f MeV/c^{2}" % binning_b)

fu.Draw()


canvas.SetLogy()
canvas
# Out:
# <ROOT.TCanvas object ("07b86a86-7101-4af1-bc53-0139bfa35657") at 0x74a1d80>

# %%
canvas = rootnotes.random_canvas(size=(1024, 768))

fu.SetXTitle("Inv. mass(J/#psi K #pi #pi), GeV/c^{2}")
fu.SetYTitle("Events / %.1f MeV/c^{2}" % binning_b)

# fu.SetAxisRange(0, 1000, 'Y')
y_axis = fu.GetYaxis()
y_axis.SetTitleOffset(1.3)
fu.Draw()

canvas
# Out:
# <ROOT.TCanvas object ("39c0fb9a-b296-4a3d-9d6a-6a965608cba5") at 0x75f4b70>

# %%
from ostap import ipython_tools

ipython_tools.params_table(ru)
# Out:
# Fit status: <b>Full, accurate covariance matrix</b><br/>minNll: <b>-278406.623356</b><br/><table><tr><th>Name</th> <th>Value</th> <th>Min</th> <th>Max</th> </tr><tr><th><font color="red">alphaAp_Bu1</font></th> <th>( 3.7 +- 0.00239627 )</th> <th>3.7</th> <th>11.0</th></tr><tr><th>nAp_Bu1</th> <th>( 0.0826966 +- 0.0546818 )</th> <th>0.0</th> <th>1000.0</th></tr><tr><th>SBu</th> <th>( 22391.2 +- 149.633 )</th> <th>0.0</th> <th>26869.2</th></tr><tr><th>sigma_Bu1</th> <th>( 0.00573473 +- 6.7755e-05 )</th> <th>0.0</th> <th>0.103923048454</th></tr><tr><th>mean_Bu1</th> <th>( 5.27965 +- 4.57197e-05 )</th> <th>5.15</th> <th>5.45</th></tr><tr><th>bAp_Bu1</th> <th>( 1.3688 +- 0.0191276 )</th> <th>1e-08</th> <th>1000.0</th></tr></table>

# %%
ru
# Out:
# RooFitResult
